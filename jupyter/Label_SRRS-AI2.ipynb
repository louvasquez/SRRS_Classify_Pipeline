# %% [markdown]
# # Label using Spacy NER

# %% [markdown]
# # Extract Messages from ANX

# %%
#!pip install chardet scikit-learn
#!pip install "accelerate>=0.26.0"
#!pip install spacy
# !pip install spacy-lookups-data
# !pip install --upgrade spacy-lookups-data
# Out:
# Requirement already satisfied: spacy-lookups-data in ./jupyter_env/lib/python3.10/site-packages (1.0.5)
# Requirement already satisfied: setuptools in ./jupyter_env/lib/python3.10/site-packages (from spacy-lookups-data) (63.2.0)
# Requirement already satisfied: spacy-lookups-data in ./jupyter_env/lib/python3.10/site-packages (1.0.5)
# Requirement already satisfied: setuptools in ./jupyter_env/lib/python3.10/site-packages (from spacy-lookups-data) (63.2.0)

# %%
# get language model
# !python -m spacy download en_core_web_sm
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-sm==3.8.0
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# check spacy
import spacy

nlp = spacy.load("en_core_web_sm")  # Load a small English model
doc = nlp("STN: KATL TEMP: 23.4C PPHRG: 5.2mm TIME: 2025-02-17T10:00Z")

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# KATL ORG
# 23.4C CARDINAL
# 5.2 CARDINAL
# 2025-02-17T10:00Z DATE

# %%
import os

# List all .anx files in the current directory
anx_files = [f for f in os.listdir('.') if f.lower().endswith('.anx')]
print("Found .anx files:", anx_files)
# Out:
# Found .anx files: ['2025012700_SRRS0021.ANX']

# %%
import chardet

with open(anx_files[0], 'rb') as file:
    result = chardet.detect(file.read(10000000))  # Read first 10KB to guess encoding
    print(result)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
# weird but detected and worked. likely just bad data with no "good" encoding
with open(anx_files[0], 'r', encoding='mac_roman') as file:
    data = file.read()

print(data[:200])  # Display the first 500 characters
# Out:
# ****0000000157****
# SRUS32 KWOH 262348
#
# RRSACR
#
# :&&HADS SOR REPORT FOR USER ACR
#
# .A ALRP7 20250126 DH2330/PPCRA 0.00
#
# .A SRGP7 20250126 DH2330/PPCRA 0.01
#
# :END OF REPORT
#
# ****0000001421****
# SRPA40 KWOH

# %%
import os

# Change the filename as needed
file_path = './2025012700_SRRS0021.ANX'

# Read the file using the detected encoding (MacRoman)
with open(file_path, 'r', encoding='mac_roman') as f:
    content = f.read()

# Print the first 2000 characters to inspect the structure
print(content[:200])
# Out:
# ****0000000157****
# SRUS32 KWOH 262348
#
# RRSACR
#
# :&&HADS SOR REPORT FOR USER ACR
#
# .A ALRP7 20250126 DH2330/PPCRA 0.00
#
# .A SRGP7 20250126 DH2330/PPCRA 0.01
#
# :END OF REPORT
#
# ****0000001421****
# SRPA40 KWOH

# %%
import re

# Header pattern, e.g. for a header like "****0000000157****"
header_pattern = re.compile(r'\*{4}\d{10}\*{4}')

# Split the file content
raw_messages = header_pattern.split(content)

# Filter out empty strings (or strings that are just whitespace)
messages = [msg for msg in raw_messages if msg.strip() != ""]

print(f"Found {len(messages)} messages.")
print("First message preview:")
print(messages[0][:500])
# Out:
# Found 3623 messages.
# First message preview:
#
# SRUS32 KWOH 262348
#
# RRSACR
#
# :&&HADS SOR REPORT FOR USER ACR
#
# .A ALRP7 20250126 DH2330/PPCRA 0.00
#
# .A SRGP7 20250126 DH2330/PPCRA 0.01
#
# :END OF REPORT

# %% [markdown]
# # Cluster Messages

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import collections

# Assume 'messages' is a list of non-empty message strings obtained from your .anx files
# For example, you might have done something like:
# raw_messages = header_pattern.split(content)
# messages = [msg for msg in raw_messages if msg.strip() != ""]

# If you have a lot of messages, you might want to work on a sample:
sample_messages = messages  # or use messages[:N] for some N

# Vectorize the messages using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english', max_features=2000)
X = vectorizer.fit_transform(sample_messages)

# Choose the number of clusters (you may experiment with this value)
num_clusters = 8
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(X)
cluster_labels = kmeans.labels_

# Print the distribution of messages across clusters
cluster_counts = collections.Counter(cluster_labels)
print("Cluster distribution:", dict(cluster_counts))

# For each cluster, print a few sample messages for inspection
for cluster in range(num_clusters):
    print(f"\nCluster {cluster} (Count: {cluster_counts[cluster]}):")
    # Select messages for this cluster
    cluster_messages = np.array(sample_messages)[cluster_labels == cluster]
    for i, msg in enumerate(cluster_messages[:1]):  # print first 3 messages from each cluster
        print(f"Message {i+1}:")
        print(msg[:300])  # print first 300 characters for preview
        print("-----")
# Out:
# Cluster distribution: {np.int32(1): 304, np.int32(4): 1025, np.int32(7): 851, np.int32(5): 279, np.int32(3): 302, np.int32(6): 277, np.int32(2): 456, np.int32(0): 129}
#
# Cluster 0 (Count: 129):
# Message 1:
#
# SRUS54 KAMA 262354
#
# HMLAMA
#
# <?xml version="1.0" standalone="yes"?>
#
# <site xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
#
#       generationtime="2025-01-26T23:54:04+00:00"
#
#       timezone="CST6CDT"
#
#       originator="AMA"
#
#       name="Canadian River 19 N Amarillo 19N"
#
#       id="AMAT2"
#
#
# -----
#
# Cluster 1 (Count: 304):
# Message 1:
#
# SRUS32 KWOH 262348
#
# RRSACR
#
# :&&HADS SOR REPORT FOR USER ACR
#
# .A ALRP7 20250126 DH2330/PPCRA 0.00
#
# .A SRGP7 20250126 DH2330/PPCRA 0.01
#
# :END OF REPORT
#
#
# -----
#
# Cluster 2 (Count: 456):
# Message 1:
#
# SRUS76 KWOH 262348
#
# RRSAMA
#
# :&&HADS SOR REPORT FOR USER AMA
#
# .A DCMT2 20250126 DH2300/PPHRG 0.00
#
# .A SPRT2 20250126 DH2300/PPHRG 0.00
#
# :END OF REPORT
#
#
# -----
#
# Cluster 3 (Count: 302):
# Message 1:
#
# SNID01 WIIX 262300 RRA
#
# AAXX 26234
#
# 96011 42460 52101 10240 20230 30049 40072 82520
#
#   333 56000 82618 83460=
#
# 96073 42456 70000 10238 20232 30060 40074 83222
#
#   333 56000 57802 83816 80859=
# -----
#
# Cluster 4 (Count: 1025):
# Message 1:
#
# SRPA40 KWOH 262348
#
# RRSHFO
#
# :&&HADS SOR REPORT FOR USER HFO
#
# .A LSFG8 20250126 DH2325/QRIRA 0.00088
#
# .A LSFG8 20250126 DH2330/QRIRA 0.00091
#
# .A LSFG8 20250126 DH2335/QRIRA 0.00088
#
# .A IMOG8 20250126 DH2325/QRIRA 0.00319
#
# .A IMOG8 20250126 DH2330/QRIRA 0.00319
#
# .A IMOG8 20250126 DH2335/QRIRA 0.00319
# -----
#
# Cluster 5 (Count: 279):
# Message 1:
#
# SACN93 KWBC 262348
#
# METAR CWPF 262345Z AUTO 03003KT 07/M02 RMK AO1 SLP298 T00671024
#
# 56010=
#
#
# -----
#
# Cluster 6 (Count: 277):
# Message 1:
#
# SRUS76 KRSA 262348
#
# RR7RSA
#
# .AR KLAO3 250125 PS DH1600/HPIRZZZ 4141.46
#
# .AR KLAO3 250125 PS DH1615/HPIRZZZ 4141.49
#
# .AR KLAO3 250125 PS DH1630/HPIRZZZ 4141.47
#
# .AR KLAO3 250125 PS DH1645/HPIRZZZ 4141.48
#
# .AR KLAO3 250125 PS DH1700/HPIRZZZ 4141.48
#
# .AR KLAO3 250125 PS DH1715/HPIRZZZ 4141.49
#
# .AR KLA
# -----
#
# Cluster 7 (Count: 851):
# Message 1:
#
# SRUS21 KWOH 262348
#
# RRSRHA
#
# :&&HADS SOR REPORT FOR USER RHA
#
# .A RCJD2 20250126 DH2310/TWIRB 32.00
#
# .A RCJD2 20250126 DH2310/QRIRA -9999
#
# .A RCJD2 20250126 DH2310/WCIRB 1570.00
#
# .A RCJD2 20250126 DH2310/WOIRB 15.00
#
# .A RCJD2 20250126 DH2310/WPIRB 7.80
#
# .A RCJD2 20250126 DH2310/WTIRB 3.50
#
# .A RCJD2 2
# -----

# %% [markdown]
# # Add Sensible Labels

# %%
import random

cluster_to_label = {
    0: "XML_SITE_REPORT",
    1: "SOR_REPORT_TEXT",
    2: "BASIC_PRECIP_REPORT",
    3: "NUMERIC_MATRIX_REPORT",
    4: "DETAILED_FORECAST_MATRIX",
    5: "AVIATION_METAR",
    6: "AVIATION_SPECIALIZED_REPORT",
    7: "SOR_REPORT_RHA"
}

# Create a list of assigned labels for each sample message:
assigned_labels = [cluster_to_label[int(cl)] for cl in cluster_labels]

# Optionally, print the first few sample messages with their assigned labels:
for i in random.sample(range(3000), 5):
    print(f"---- Message {i+1} (Cluster {cluster_labels[i]}): {assigned_labels[i]}")
    print("\n".join(filter(str.strip, sample_messages[i][:70].splitlines())))
    #print(sample_messages[i][:100])  # preview the first 300 characters
# Out:
# ---- Message 360 (Cluster 6): AVIATION_SPECIALIZED_REPORT
# SRUS69 KWOH 262349
# RRSLCH
# :&&AFWS REPORT FOR USER LCH
# .E JZVT2 250
# ---- Message 1961 (Cluster 1): SOR_REPORT_TEXT
# SXUS77 KWOH 262356
# RRSEKA
# :&&HADS SOR REPORT FOR USER EKA
# .A ALDC1
# ---- Message 1220 (Cluster 3): NUMERIC_MATRIX_REPORT
# SOVD83 KWNB 262200 RRX
# KKYY 26015 2245/ 728138 096829 88871 83099 20
# ---- Message 737 (Cluster 4): DETAILED_FORECAST_MATRIX
# SRUS21 KWOH 262350
# RRSRHA
# :&&HADS SOR REPORT FOR USER RHA
# .E BWSW2
# ---- Message 2795 (Cluster 3): NUMERIC_MATRIX_REPORT
# SMVD01 KWBC 270000 RRA
# BBXX
# 42058 27001 99145 70752 46/// /0710 102

# %%
import pandas as pd

# Assume you have:
# sample_messages: a list of message strings
# cluster_labels: a list/array of cluster numbers (one for each message)
# assigned_labels: a list of descriptive labels corresponding to each message

# Create a DataFrame from your lists
df = pd.DataFrame({
    'message': sample_messages,
    'cluster': cluster_labels,
    'label': assigned_labels
})

# Save the DataFrame to a CSV file
df.to_csv("labeled_dataset.csv", index=False, escapechar="\\")
print("Labeled dataset saved to labeled_dataset.csv")
# Out:
# Labeled dataset saved to labeled_dataset.csv

# %% [markdown]
# # Train Model
#
# Labeled data has been saved to CSV.
# - load csv
# - train model on labeled data

# %%
# Example of saving training data
#
# TRAIN_DATA.append(
#     ("SRUS32 KDFW 272348 RRSACR "
#      ".A STN1 20250227 DH1200/PPCRA 2.50 "
#      ".A STN2 20250227 DH1300/PPCRA 1.80 "
#      ".A STN3 20250227 DH1400/PPCRA 0.00",
#      {"entities": [
#          (7, 11, "STATION_ID"),       # "KDFW"
#          (12, 18, "TIMESTAMP"),       # "272348"
#          (20, 26, "REPORT_TYPE"),     # "RRSACR"

#          (29, 31, "PREFIX"),          # ".A"
#          (32, 36, "STATION_ID"),      # "STN1"
#          (37, 45, "DATE"),            # "20250227"
#          (46, 52, "TIME"),            # "DH1200"
#          (53, 65, "PRECIPITATION"),   # "PPCRA 2.50"
#      ]}
#     )
# )
# print(json.dumps(TRAIN_DATA))
# with open("srrs_train_data2.json", "w", encoding="utf-8") as file:
#     json.dump(TRAIN_DATA, file, indent=4)

TRAIN_DATA = [
    (
        "SRUS32 KWOH 262348 RRSACR :&&HADS SOR REPORT FOR USER ACR "
        ".A ALRP7 20250126 DH2330/PPCRA 0.00 "
        ".A SRGP7 20250126 DH2330/PPCRA 0.01 :END OF REPORT",
        {
            "entities": [
                (0, 6, "PRODUCT_ID"),
                (7, 11, "STATION_ID"),
                (12, 18, "TIMESTAMP"),
                (19, 25, "REPORT_TYPE"),
                (52, 55, "USER_ID"),
                (59, 64, "STATION_ID"),
                (65, 73, "DATE"),
                (74, 80, "TIME"),
                (81, 92, "PRECIPITATION"),
                (95, 100, "STATION_ID"),
                (101, 109, "DATE"),
                (110, 116, "TIME"),
                (117, 128, "PRECIPITATION")
            ]
        }
    )
]
print(json.dumps(TRAIN_DATA))
with open("srrs_train_data2.json", "w", encoding="utf-8") as file:
    json.dump(TRAIN_DATA, file, indent=4)
# Out:
# [["SRUS32 KWOH 262348 RRSACR :&&HADS SOR REPORT FOR USER ACR .A ALRP7 20250126 DH2330/PPCRA 0.00 .A SRGP7 20250126 DH2330/PPCRA 0.01 :END OF REPORT", {"entities": [[0, 6, "PRODUCT_ID"], [7, 11, "STATION_ID"], [12, 18, "TIMESTAMP"], [19, 25, "REPORT_TYPE"], [52, 55, "USER_ID"], [59, 64, "STATION_ID"], [65, 73, "DATE"], [74, 80, "TIME"], [81, 92, "PRECIPITATION"], [95, 100, "STATION_ID"], [101, 109, "DATE"], [110, 116, "TIME"], [117, 128, "PRECIPITATION"]]}]]

# %% [markdown]
# # Train and save NER model

# %%
import spacy
import json
from spacy.training.example import Example

# MUST LOAD with...    python -m spacy download en_core_web_sm
# small was bad at labeling "en_core_web_sm"
nlp = spacy.load("en_core_web_lg")

with open("srrs_train_data.json", "r", encoding="utf-8") as file:
    training_data = json.load(file)
print("Training Data Loaded:")
    
# raise KeyboardInterrupt  # Stops only this cell
    
optimizer = nlp.begin_training()
for epoch in range(20):  # More epochs = better learning
    for text, annotations in training_data:
        example = Example.from_dict(nlp.make_doc(text), annotations)
        nlp.update([example], drop=0.3)

# Save the trained model
nlp.to_disk("custom_srrs_ner")

print("Training complete! Model saved as 'custom_srrs_ner'")
# Out:
# Training Data Loaded:
# /Users/lou/jupyter/jupyter_env/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SRUS32 KDFW 272348 RRSACR .A STN1 20250227 DH1200/..." with entities "[[7, 11, 'STATION_ID'], [12, 18, 'TIMESTAMP'], [20...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/lou/jupyter/jupyter_env/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SMVX90 KWBC 262348 RRA BBXX 9HXD9 2622/ 99245 7081..." with entities "[[0, 6, 'PRODUCT_ID'], [7, 11, 'STATION_ID'], [12,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /Users/lou/jupyter/jupyter_env/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SRUS32 KWOH 262348 RRSACR :&&HADS SOR REPORT FOR U..." with entities "[[0, 6, 'PRODUCT_ID'], [7, 11, 'STATION_ID'], [12,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Training complete! Model saved as 'custom_srrs_ner'

# %%
import json

from datasets import load_dataset, DatasetDict

dataset = load_dataset("csv", data_files={"data": "labeled_dataset.csv"}, split="data")
print(dataset)

nlp = spacy.load("custom_srrs_ner")


for index,msg in enumerate(dataset):
    if index>10:
        break
    doc = nlp(msg["message"])
    print("\n📌 Inferred Entities:")
    for ent in doc.ents:
        print(f"Entity: {ent.text} | Label: {ent.label_}")
    
raise KeyboardInterrupt  # Stops only this cell
# Out:
# Dataset({
#     features: ['message', 'cluster', 'label'],
#     num_rows: 3623
# })
#
# 📌 Inferred Entities:
# Entity: SRUS32 | Label: PRODUCT_ID
# Entity: KWOH | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
# Entity: RRSACR | Label: REPORT_TYPE
#
# 📌 Inferred Entities:
# Entity: SRPA40 | Label: TIMESTAMP
# Entity: KWOH | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
#
# 📌 Inferred Entities:
# Entity: SRUS21 | Label: PRODUCT_ID
# Entity: KWOH | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
# Entity: RRSRHA | Label: REPORT_TYPE
# Entity: RHA | Label: REPORT_TYPE
#
# 📌 Inferred Entities:
# Entity: SRUS47 | Label: TIMESTAMP
# Entity: KWOH | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
#
# 📌 Inferred Entities:
# Entity: SRPA41 | Label: TIMESTAMP
# Entity: KWOH | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
#
# 📌 Inferred Entities:
# Entity: SXUS35 | Label: PRODUCT_ID
# Entity: KWOH | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
#
# 📌 Inferred Entities:
# Entity: SRUS28 | Label: TIMESTAMP
# Entity: KWOH | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
#
# 📌 Inferred Entities:
# Entity: KWBC | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
# Entity: RMK | Label: REPORT_TYPE
# Entity: T00671024 | Label: STATION_ID
#
# 📌 Inferred Entities:
# Entity: KWBC | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
# Entity: AAA | Label: REPORT_TYPE
# Entity: KLCH | Label: STATION_ID
#
# 📌 Inferred Entities:
# Entity: SMVX90 | Label: PRODUCT_ID
# Entity: KWBC | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: WBP3210 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 31579 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 70814 | Label: REPORT_TYPE
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 40343 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22223 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 8/14/ | Label: STATION_ID
# Entity: 22274 | Label: TIMESTAMP
# Entity: 22273 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99113 | Label: STATION_ID
# Entity: 31270 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22244 | Label: TIMESTAMP
# Entity: 55017 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 10708 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22263 | Label: TIMESTAMP
# Entity: 22211 | Label: TIMESTAMP
# Entity: 20100 | Label: TIMESTAMP
# Entity: 99240 | Label: STATION_ID
# Entity: 22235 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 70801 | Label: REPORT_TYPE
# Entity: 22253 | Label: TIMESTAMP
# Entity: 22273 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22263 | Label: TIMESTAMP
# Entity: 31488 | Label: TIMESTAMP
# Entity: 20273 | Label: TIMESTAMP
# Entity: 22253 | Label: TIMESTAMP
# Entity: 56018 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22282 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 40231 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 99515 | Label: STATION_ID
# Entity: 10015 | Label: REPORT_TYPE
# Entity: 22253 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 10864 | Label: TIMESTAMP
# Entity: 56018 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 22265 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22235 | Label: TIMESTAMP
# Entity: 55001 | Label: STATION_ID
# Entity: 99208 | Label: STATION_ID
# Entity: 11071 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22263 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 40255 | Label: STATION_ID
# Entity: 55017 | Label: TIMESTAMP
# Entity: 22274 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 40244 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 40199 | Label: REPORT_TYPE
# Entity: 40101 | Label: TIMESTAMP
# Entity: 58020 | Label: REPORT_TYPE
# Entity: 51018 | Label: PRESSURE
# Entity: 22274 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22213 | Label: TIMESTAMP
# Entity: 40029 | Label: TIMESTAMP
# Entity: 58046 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 8//// | Label: STATION_ID
# Entity: 22264 | Label: TIMESTAMP
# Entity: 40237 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 40313 | Label: TIMESTAMP
# Entity: 40077 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22223 | Label: TIMESTAMP
# Entity: 22264 | Label: TIMESTAMP
# Entity: WDB9918 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99274 | Label: REPORT_TYPE
# Entity: 70963 | Label: TIMESTAMP
# Entity: 10094 | Label: TIMESTAMP
# Entity: 40116 | Label: STATION_ID
# Entity: 70801 | Label: REPORT_TYPE
# Entity: 40105 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22263 | Label: TIMESTAMP
# Entity: 22264 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 22264 | Label: TIMESTAMP
# Entity: WBP3210 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 49843 | Label: REPORT_TYPE
# Entity: 53035 | Label: TIMESTAMP
# Entity: 22274 | Label: TIMESTAMP
# Entity: 22271 | Label: TIMESTAMP
# Entity: 70801 | Label: REPORT_TYPE
# Entity: 11630 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 40167 | Label: REPORT_TYPE
# Entity: 40257 | Label: TIMESTAMP
# Entity: 56018 | Label: TEMPERATURE
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99250 | Label: REPORT_TYPE
# Entity: 03609 | Label: TIMESTAMP
# Entity: 702// | Label: TIMESTAMP
# Entity: 22235 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99231 | Label: REPORT_TYPE
# Entity: 40604 | Label: TIMESTAMP
# Entity: 99529 | Label: STATION_ID
# Entity: 10043 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22213 | Label: TIMESTAMP
# Entity: 22274 | Label: TIMESTAMP
# Entity: 22253 | Label: TIMESTAMP
# Entity: 22264 | Label: TIMESTAMP
# Entity: 53010 | Label: STATION_ID
# Entity: 8//// | Label: STATION_ID
# Entity: 22284 | Label: TIMESTAMP
# Entity: 70801 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 40179 | Label: REPORT_TYPE
# Entity: 40265 | Label: REPORT_TYPE
# Entity: 56018 | Label: STATION_ID
# Entity: 8//// | Label: STATION_ID
# Entity: 22261 | Label: TIMESTAMP
# Entity: 70801 | Label: REPORT_TYPE
# Entity: 40244 | Label: TIMESTAMP
# Entity: 55001 | Label: STATION_ID
# Entity: 22264 | Label: TIMESTAMP
# Entity: 99240 | Label: STATION_ID
# Entity: 70877 | Label: TIMESTAMP
# Entity: 56026 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22244 | Label: TIMESTAMP
# Entity: 22273 | Label: TIMESTAMP
# Entity: 22235 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22213 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 22213 | Label: TIMESTAMP
# Entity: 40268 | Label: REPORT_TYPE
# Entity: 22222 | Label: TIMESTAMP
# Entity: 70801 | Label: REPORT_TYPE
# Entity: 40238 | Label: REPORT_TYPE
#
# 📌 Inferred Entities:
# Entity: SMVX90 | Label: PRODUCT_ID
# Entity: KWBC | Label: STATION_ID
# Entity: 262348 | Label: TIMESTAMP
# Entity: RRA | Label: REPORT_TYPE
# Entity: 40081 | Label: TEMPERATURE
# Entity: 51018 | Label: PRESSURE
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 99119 | Label: STATION_ID
# Entity: 11202 | Label: TIMESTAMP
# Entity: 20242 | Label: TIMESTAMP
# Entity: 22221 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 22221 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 40248 | Label: TIMESTAMP
# Entity: 22253 | Label: TIMESTAMP
# Entity: 40101 | Label: TIMESTAMP
# Entity: 55023 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 99535 | Label: STATION_ID
# Entity: 10099 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 40162 | Label: TIMESTAMP
# Entity: 56021 | Label: REPORT_TYPE
# Entity: 10026 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 8//// | Label: STATION_ID
# Entity: 22263 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: VDCY | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99437 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: CFN5191 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99421 | Label: REPORT_TYPE
# Entity: 70814 | Label: REPORT_TYPE
# Entity: 222// | Label: TIMESTAMP
# Entity: CHAC | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 9HA5025 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99419 | Label: REPORT_TYPE
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99446 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99385 | Label: REPORT_TYPE
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99496 | Label: REPORT_TYPE
# Entity: 222// | Label: TIMESTAMP
# Entity: 40268 | Label: REPORT_TYPE
# Entity: 56019 | Label: REPORT_TYPE
# Entity: 8//// | Label: STATION_ID
# Entity: 22223 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22275 | Label: TIMESTAMP
# Entity: 22274 | Label: TIMESTAMP
# Entity: 40187 | Label: STATION_ID
# Entity: 22235 | Label: TIMESTAMP
# Entity: WYM9567 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99611 | Label: REPORT_TYPE
# Entity: WDE7804 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: WDG2803 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99609 | Label: REPORT_TYPE
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99578 | Label: REPORT_TYPE
# Entity: 40309 | Label: REPORT_TYPE
# Entity: WDK5676 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99594 | Label: REPORT_TYPE
# Entity: 41999 | Label: TIMESTAMP
# Entity: 00906 | Label: REPORT_TYPE
# Entity: 10230 | Label: TIMESTAMP
# Entity: 22282 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 80239 | Label: TIMESTAMP
# Entity: 324// | Label: STATION_ID
# Entity: V7A6440 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 50920 | Label: STATION_ID
# Entity: 10260 | Label: TIMESTAMP
# Entity: 20504 | Label: TIMESTAMP
# Entity: 56016 | Label: REPORT_TYPE
# Entity: 40224 | Label: TIMESTAMP
# Entity: 50005 | Label: REPORT_TYPE
# Entity: 22273 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: C6RN3 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 87464 | Label: STATION_ID
# Entity: 22224 | Label: TIMESTAMP
# Entity: 50706 | Label: TIMESTAMP
# Entity: VRJT5 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99153 | Label: STATION_ID
# Entity: 10604 | Label: TIMESTAMP
# Entity: 30213 | Label: TIMESTAMP
# Entity: 20195 | Label: TIMESTAMP
# Entity: 40602 | Label: TIMESTAMP
# Entity: 40105 | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 22263 | Label: TIMESTAMP
# Entity: WBP3210 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 49845 | Label: REPORT_TYPE
# Entity: 53033 | Label: REPORT_TYPE
# Entity: 3ETR7 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99429 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: VDCY | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99437 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99192 | Label: REPORT_TYPE
# Entity: CFN5191 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99421 | Label: REPORT_TYPE
# Entity: CHAC | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 9HA5025 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99419 | Label: REPORT_TYPE
# Entity: 70829 | Label: REPORT_TYPE
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99446 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: WYM9567 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99611 | Label: REPORT_TYPE
# Entity: WDE7804 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: WDG2803 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99609 | Label: REPORT_TYPE
# Entity: 20014 | Label: TIMESTAMP
# Entity: 40154 | Label: REPORT_TYPE
# Entity: WDI6469 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: WDK5676 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99594 | Label: REPORT_TYPE
# Entity: WDK8035 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99578 | Label: REPORT_TYPE
# Entity: 222// | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 9HA5823 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 9V2783 | Label: STATION_ID
# Entity: 25224 | Label: TIMESTAMP
# Entity: 99237 | Label: REPORT_TYPE
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 9V2783 | Label: STATION_ID
# Entity: 26024 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 9V2783 | Label: STATION_ID
# Entity: 99237 | Label: REPORT_TYPE
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 9V2783 | Label: STATION_ID
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 3FOA6 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 702// | Label: TIMESTAMP
# Entity: 8//// | Label: STATION_ID
# Entity: 20116 | Label: TIMESTAMP
# Entity: 06140 | Label: REPORT_TYPE
# Entity: 11539 | Label: TIMESTAMP
# Entity: 53016 | Label: STATION_ID
# Entity: 41/98 | Label: STATION_ID
# Entity: 23007 | Label: TIMESTAMP
# Entity: 10189 | Label: REPORT_TYPE
# Entity: 26224 | Label: TIMESTAMP
# Entity: VDCY | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99437 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: CFN5191 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99421 | Label: REPORT_TYPE
# Entity: CHAC | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 9HA5025 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99419 | Label: REPORT_TYPE
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99446 | Label: TIMESTAMP
# Entity: 222// | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99302 | Label: STATION_ID
# Entity: WDE7804 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: WYM9567 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99611 | Label: REPORT_TYPE
# Entity: 57018 | Label: REPORT_TYPE
# Entity: WDG2803 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99609 | Label: REPORT_TYPE
# Entity: WDK8035 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99578 | Label: REPORT_TYPE
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99511 | Label: REPORT_TYPE
# Entity: WDK5676 | Label: STATION_ID
# Entity: 26224 | Label: TIMESTAMP
# Entity: 99594 | Label: REPORT_TYPE
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 26064 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# Entity: 10280 | Label: TIMESTAMP
# Entity: 54000 | Label: TIMESTAMP
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 22
#      19     for ent in doc.ents:
#      20         print(f"Entity: {ent.text} | Label: {ent.label_}")
# ---> 22 raise KeyboardInterrupt  # Stops only this cell
#
# KeyboardInterrupt:
